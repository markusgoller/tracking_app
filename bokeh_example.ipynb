# %% [markdown]
# # Random Examples

# %% [markdown]
# #### https://bokeh.pydata.org/en/latest/docs/user_guide/quickstart.html#sample-data

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import ColumnDataSource, CustomJS

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
x = [2, 3, 5, 6, 8, 7]
y = [6, 4, 3, 8, 7, 5]

# %%
p = figure(width=400, height=400, tools="hover", toolbar_location=None, title='Hovering over point:')

# %%
cr = p.circle(x, y, color='olive', radius=1, alpha=0.4, hover_color='olive', hover_alpha=1.0)

# %%
callback = CustomJS(args={'title': p.title}, code="""
    const indices = cb_data.index.indices;
    title.text = 'Hovering over points: ' + indices
""")

p.hover.tooltips=None
p.hover.callback=callback

# %%
show(p)
# Out:
#   <div class="bk-root" id="441a4e21-a804-488e-8273-c5bcd5a71305" data-root-id="1002"></div>

# %% [markdown]
# # Hover Examples

# %%
from bokeh.plotting import figure, output_file, output_notebook, show

# prepare some data
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]

# output to static HTML file
#output_file("lines.html")

# Output Notebook
output_notebook()

# create a new plot with a title and axis labels
p = figure(title="simple line example", x_axis_label='x', y_axis_label='y')

# add a line renderer with legend and line thickness
p.line(x, y, legend="Temp.", line_width=2)

# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1084">Loading BokehJS ...</span>
#     </div>
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
#   <div class="bk-root" id="643d2671-2981-43a7-b3c8-d7a77296db63" data-root-id="1085"></div>

# %% [markdown]
# # Hover

# %% [markdown]
# ### Execute only onces

# %% [markdown]
# ### To load data e.g. APPL vom repository

# %% [raw]
# !bokeh sampledata

# %%
import numpy as np

from bokeh.io import output_file, output_notebook, show
from bokeh.models import ColumnDataSource, HoverTool
from bokeh.plotting import figure
from bokeh.sampledata.stocks import AAPL

#output_file("tools_hover_tooltip_formatting.html")
output_notebook()

def datetime(x):
    return np.array(x, dtype=np.datetime64)

source = ColumnDataSource(data={
    'date'      : datetime(AAPL['date'][::10]),
    'adj close' : AAPL['adj_close'][::10],
    'volume'    : AAPL['volume'][::10],
})

p = figure(plot_height=250, x_axis_type="datetime", tools="", toolbar_location=None,
           title="Hover Tooltip Formatting", sizing_mode="scale_width")
p.background_fill_color="#f5f5f5"
p.grid.grid_line_color="white"
p.xaxis.axis_label = 'Date'
p.yaxis.axis_label = 'Price'
p.axis.axis_line_color = None

p.line(x='date', y='adj close', line_width=2, color='#ebbd5b', source=source)

p.add_tools(HoverTool(
    tooltips=[
        ( 'date',   '@date{%F}'            ),
        ( 'close',  '$@{adj close}{%0.2f}' ), # use @{ } for field names with spaces
        ( 'volume', '@volume{0.00 a}'      ),
    ],

    formatters={
        'date'      : 'datetime', # use 'datetime' formatter for 'date' field
        'adj close' : 'printf',   # use 'printf' formatter for 'adj close' field
                                  # use default 'numeral' formatter for other fields
    },

    # display a tooltip whenever the cursor is vertically in line with a glyph
    mode='vline'
))

show(p)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-292595629f4e> in <module>()
#       4 from bokeh.models import ColumnDataSource, HoverTool
#       5 from bokeh.plotting import figure
# ----> 6 from bokeh.sampledata.stocks import AAPL
#       7
#       8 #output_file("tools_hover_tooltip_formatting.html")
#
# /home/unix/anaconda3/envs/python_2_7/lib/python2.7/site-packages/bokeh/sampledata/stocks.py in <module>()
#     100 #-----------------------------------------------------------------------------
#     101
# --> 102 AAPL = _read_data('AAPL')
#     103 FB   = _read_data('FB')
#     104 GOOG = _read_data('GOOG')
#
# /home/unix/anaconda3/envs/python_2_7/lib/python2.7/site-packages/bokeh/sampledata/stocks.py in _read_data(name)
#      72
#      73     '''
# ---> 74     filename = external_path(name+'.csv')
#      75     data = {
#      76         'date' : [],
#
# /home/unix/anaconda3/envs/python_2_7/lib/python2.7/site-packages/bokeh/util/sampledata.pyc in external_path(filename)
#     127
#     128 def external_path(filename):
# --> 129     data_dir = external_data_dir()
#     130     fn = join(data_dir, filename)
#     131     if not exists(fn) and isfile(fn):
#
# /home/unix/anaconda3/envs/python_2_7/lib/python2.7/site-packages/bokeh/util/sampledata.pyc in external_data_dir(create)
#     114     if not exists(data_dir):
#     115         if not create:
# --> 116             raise RuntimeError('bokeh sample data directory does not exist, please execute bokeh.sampledata.download()')
#     117         print("Creating %s directory" % data_dir)
#     118         try:
#
# RuntimeError: bokeh sample data directory does not exist, please execute bokeh.sampledata.download()
