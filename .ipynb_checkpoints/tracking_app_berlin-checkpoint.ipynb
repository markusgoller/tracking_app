# %% [markdown]
# # tracking_app

# %% [markdown]
# ## Load Data

# %%
# %load_ext autoreload
# %autoreload
# %matplotlib inline
import gpxpy
import matplotlib.pyplot as plt
import datetime
#from geopy import distance
from math import sqrt, floor
import numpy as np
import pandas as pd
#import plotly.plotly as py
#import plotly.graph_objs as go
import haversine

# %% [markdown]
# #### https://towardsdatascience.com/how-tracking-apps-analyse-your-gps-data-a-hands-on-tutorial-in-python-756d4db6715d

# %% [markdown]
# ## Data taken from Amazfit Stratos Watch

# %%
# Amazfit Stratos
#gpx_file = open('./data/history-2020-08-20_biketour_to_airport.gpx', 'r')
gpx_file = open('./data/history-2020-08-19.gpx', 'r')
gpx = gpxpy.parse(gpx_file)

print(gpx)
# Out:
# GPX(tracks=[GPXTrack(name=u'Walking', segments=[GPXTrackSegment(points=[...])]), GPXTrack(name=u'Walking', segments=[GPXTrackSegment(points=[...])]), GPXTrack(name=u'Walking', segments=[GPXTrackSegment(points=[...])]), GPXTrack(name=u'Walking', segments=[GPXTrackSegment(points=[...])]), GPXTrack(name=u'Walking', segments=[GPXTrackSegment(points=[...])]), GPXTrack(name=u'Cycling', segments=[GPXTrackSegment(points=[...])]), GPXTrack(name=u'Cycling', segments=[GPXTrackSegment(points=[...])]), GPXTrack(name=u'Walking', segments=[GPXTrackSegment(points=[...])]), GPXTrack(name=u'Walking', segments=[GPXTrackSegment(points=[...])]), GPXTrack(name=u'Cycling', segments=[GPXTrackSegment(points=[...])]), GPXTrack(name=u'Walking', segments=[GPXTrackSegment(points=[...])]), GPXTrack(name=u'Cycling', segments=[GPXTrackSegment(points=[...])]), GPXTrack(name=u'Cycling', segments=[GPXTrackSegment(points=[...])])])

# %% [markdown]
# ## Merge, Positions

# %%
## Merge, Positions

data = gpx.tracks[0].segments[0].points
#print('data:', data)

# Start Position
start = data[0]
print('start:', start)

# End Position
finish = data[-1]
print('finish', finish)
# Out:
# ('start:', GPXTrackPoint(52.500414, 13.3467471))
# ('finish', GPXTrackPoint(52.5016021, 13.340993))

# %% [markdown]
# ## Dataframe

# %%
df = pd.DataFrame(columns=['lon', 'lat', 'alt', 'time'])
for point in data:
    df = df.append({'lon': point.longitude, 'lat' : point.latitude, 
                    'alt' : point.elevation, 'time' : point.time}, 
                   ignore_index=True)

df.describe()
# Out:
#              lon        lat  alt  time
# count   6.000000   6.000000  0.0   0.0
# mean   13.344034  52.501300  NaN   NaN
# std     0.002616   0.000800  NaN   NaN
# min    13.340993  52.500414  NaN   NaN
# 25%    13.341680  52.500626  NaN   NaN
# 50%    13.344363  52.501432  NaN   NaN
# 75%    13.346306  52.501602  NaN   NaN
# max    13.346747  52.502504  NaN   NaN

# %% [markdown]
# ## All the points

# %%
print(df['lon'])
print(df['lat'])
# Out:
# 0    13.346747
# 1    13.346747
# 2    13.344984
# 3    13.343742
# 4    13.340993
# 5    13.340993
# Name: lon, dtype: float64
# 0    52.500414
# 1    52.500414
# 2    52.501262
# 3    52.502504
# 4    52.501602
# 5    52.501602
# Name: lat, dtype: float64

# %% [markdown]
# ## Plots

# %%
plt.xticks(rotation=30)
plt.plot(df['lon'], df['lat'])

# %%
plt.xticks(rotation=30)
plt.plot(df['time'], df['alt'])

# %% [markdown]
# ## Basemap

# %% [markdown]
# ##### # http://www.datasciencemadesimple.com/get-maximum-value-column-python-pandas/

# %%
# Make edge for basemap
lon_lat_add = .005
lon_min = df['lon'].min() - lon_lat_add
lon_max = df['lon'].max() + lon_lat_add

lat_min = df['lat'].min() - lon_lat_add
lat_max = df['lat'].max() + lon_lat_add

# %%
from mpl_toolkits.basemap import Basemap


m = Basemap(  
            llcrnrlon=lon_min, urcrnrlon=lon_max,    
            llcrnrlat=lat_min, urcrnrlat=lat_max,
            epsg=4269,    # Default
            ) 
m.arcgisimage(#service='World_Topo_Map',    # Straßenkarte grobskalig   
              #service='World_Terrain_Base',   # Does not work
              #service='Elevation/ESRI_Elevation_World',   # Does not work
              #service='ESRI_Imagery_World_2D',   
              xpixels = 1000,    # Default 1000, 100 bei World_Topo_Map  
              verbose= True,
              dpi=300
              )
m.plot(df['lon'], df['lat'])
# Out:
# http://server.arcgisonline.com/ArcGIS/rest/services/ESRI_Imagery_World_2D/MapServer/export?bbox=13.335993,52.495414,13.3517471,52.5075037&bboxSR=4269&imageSR=4269&size=1000,767&dpi=300&format=png32&transparent=true&f=image
